# %% [markdown]
# # **Introduction**
#
# **Project Type:** Capstone Pair Project
# <br><br>
# **Project Title:** Laptop Price Predictor using Machine Learning
#
# ![image.png](data:image/png;base64,...)
